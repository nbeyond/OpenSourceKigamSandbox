# %% [markdown]
# # Day 2
# * Python dasic
# * Markdown
#
# $ y=log_a x^b $

# %%
print ('안녕하세요')
# Out:
# 안녕하세요

# %%
안녕하세요 = 3
뭐하니  = 5
그냥 = 안녕하세요 + 뭐하니
print (그냥)
# Out:
# 8

# %%
import pandas

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F279-F714
#
#  Directory of C:\git\OpenSourceKigamSandbox\python
#
# 2020-12-09  오후 02:27    <DIR>          .
# 2020-12-09  오후 02:27    <DIR>          ..
# 2020-12-09  오후 02:13    <DIR>          .ipynb_checkpoints
# 2020-12-08  오후 02:50               575 bashrc
# 2020-12-08  오후 05:00             1,197 Day 1 PCH.ipynb
# 2020-12-08  오후 05:11             1,178 Day 1 PDK.ipynb
# 2020-12-08  오후 05:11             1,746 Day 1 YBJung.ipynb
# 2020-12-08  오후 04:52             1,099 Day 1 YCha.ipynb
# 2020-12-09  오후 01:35               585 Day1_commands.md
# 2020-12-09  오후 01:34             1,185 Day1_KHW.ipynb
# 2020-12-09  오후 01:53               188 Day2_commands.md
# 2020-12-09  오후 02:27             1,464 Untitled.ipynb
# 2020-12-08  오후 04:24             2,173 Useful_command_KTH.md
#               10 File(s)         11,390 bytes
#                3 Dir(s)  35,784,437,760 bytes free

# %%
path='usagov_bitly_data2012-03-16-1331923249.txt'
open(path).readline() # path 파일의 라인 하나를 읽은것
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import json
records = [json.loads(line) for line in open(path, 'rt', encoding='UTF8')] # for 문에서 rt 라인을 계속 읽어라! UTF는 다양한 문자를 핸들할 수 있게 만든 규약

# %%
records[0]
# Out:
# {'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  'c': 'US',
#  'nk': 1,
#  'tz': 'America/New_York',
#  'gr': 'MA',
#  'g': 'A6qOVH',
#  'h': 'wfLQtf',
#  'l': 'orofrog',
#  'al': 'en-US,en;q=0.8',
#  'hh': '1.usa.gov',
#  'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991',
#  't': 1331923247,
#  'hc': 1331822918,
#  'cy': 'Danvers',
#  'll': [42.576698, -70.954903]}

# %%
records[0]['tz']
# Out:
# 'America/New_York'

# %%
print('안녕'+'하세요')
type (records) # records의 타입을 나타냄
# Out:
# 안녕하세요
# list

# %%
import pandas
frame = pandas.DataFrame(records) # pandas에서 데이터 프레임에 데이터를 넣는다.

# %%
type(frame)
# Out:
# pandas.core.frame.DataFrame

# %%
frame
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %%
frame['tz'][:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
frame['tz'][2:10]
# Out:
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
tz_counts=frame['tz'].value_counts()

# %%
tz_counts[0:10] # 상위 10개 빈도수로 나열
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
clean_tz = frame['tz'].fillna('missing')

# %%
clean_tz
# Out:
# 0          America/New_York
# 1            America/Denver
# 2          America/New_York
# 3         America/Sao_Paulo
# 4          America/New_York
#                ...
# 3555       America/New_York
# 3556        America/Chicago
# 3557         America/Denver
# 3558    America/Los_Angeles
# 3559       America/New_York
# Name: tz, Length: 3560, dtype: object

# %%
clean_tz[clean_tz==''] = 'unknown' # missing이 안되는 애들은 unknown으로 나타낸다.

# %%
clean_tz[0:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7              unknown
# 8              unknown
# 9              unknown
# Name: tz, dtype: object

# %%
type(clean_tz)
# Out:
# pandas.core.series.Series

# %%
tz_counts = clean_tz.value_counts () # clean 한 타임존의 value count

# %%
tz_counts [0:-10]
# Out:
# America/New_York       1251
# unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
#                        ...
# Asia/Kuching              1
# America/Mazatlan          1
# America/Costa_Rica        1
# Europe/Ljubljana          1
# Asia/Pontianak            1
# Name: tz, Length: 88, dtype: int64

# %%
# %matplotlib inline

# %%
tz_counts[:10].plot(kind='barh', rot=0)  # 바차트로 수직으로
# Out:
# <AxesSubplot:>

# %%
frame['a'][1]
# Out:
# 'GoogleMaps/RochesterNY'

# %%
frame['a']
# Out:
# 0       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1                                  GoogleMaps/RochesterNY
# 2       Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#                               ...
# 3555    Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...
# 3556    Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 3557                               GoogleMaps/RochesterNY
# 3558                                       GoogleProducer
# 3559    Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# Name: a, Length: 3560, dtype: object

# %%
frame['a'].dropna() # 데이터가 없는 라인을 버려라 dropna
# Out:
# 0       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1                                  GoogleMaps/RochesterNY
# 2       Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#                               ...
# 3555    Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...
# 3556    Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 3557                               GoogleMaps/RochesterNY
# 3558                                       GoogleProducer
# 3559    Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# Name: a, Length: 3440, dtype: object

# %%
len(frame['a'].dropna())
# Out:
# 3440

# %%
len(frame['a'])
# Out:
# 3560

# %%
clean_a=frame['a'].dropna()

# %%
len(clean_a)
# Out:
# 3440

# %%
for x in clean_a:
    print(x)
# Out:
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11
# GoogleMaps/RochesterNY
# Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.52.7 (KHTML, like Gecko) Version/5.1.2 Safari/534.52.7
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11
# Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11
# Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/20100101 Firefox/4.0.1
# Opera/9.80 (X11; Linux zbov; U; en) Presto/2.10.254 Version/12.00
# ...

# %%
agents=[x for x in clean_a]

# %%
agent_1=agents[0]

# %%
agent_1
# Out:
# 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11'

# %%
agent_1.split()
# Out:
# ['Mozilla/5.0',
#  '(Windows',
#  'NT',
#  '6.1;',
#  'WOW64)',
#  'AppleWebKit/535.11',
#  '(KHTML,',
#  'like',
#  'Gecko)',
#  'Chrome/17.0.963.78',
#  'Safari/535.11']

# %%
agent_1.split(';')
# Out:
# ['Mozilla/5.0 (Windows NT 6.1',
#  ' WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11']

# %%
agent_1.split()[0]
# Out:
# 'Mozilla/5.0'

# %%
agent_1.split(')')
# Out:
# ['Mozilla/5.0 (Windows NT 6.1; WOW64',
#  ' AppleWebKit/535.11 (KHTML, like Gecko',
#  ' Chrome/17.0.963.78 Safari/535.11']

# %%
agent_1.split(')')[1]
# Out:
# ' AppleWebKit/535.11 (KHTML, like Gecko'

# %%
results = pandas.Series([x.split()[0] for x in frame.a.dropna()]) # ['a'] 또는 a 쓰는 방법은 두가지다.

# %%
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results = pandas.Series([x.split()[0] for x in frame['a'].dropna()])
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts()[:8]
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# dtype: int64

# %%
cframe = frame[frame.a.notnull()]

# %%
cframe
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...
